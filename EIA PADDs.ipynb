# %%
from cornerstone import *

# %%
start='2014-01-03'
end='2018-10-30'
rcParams['figure.figsize'] = 18, 18

# %%
#Crude Oil
stock1_w=eia_w('PET.WCESTP11.W','PADD1 Stock')[start:end]
stock2_w=eia_w('PET.WCESTP21.W','PADD2 Stock')[start:end]
stock3_w=eia_w('PET.WCESTP31.W','PADD3 Stock')[start:end]
stock4_w=eia_w('PET.WCESTP41.W','PADD4 Stock')[start:end]
stock5_w=eia_w('PET.WCESTP51.W','PADD5 Stock')[start:end]
#imp1_w=eia_w('PET.WCEIMP12.W','PADD1 Import')[start:end]
#imp2_w=eia_w('PET.WCEIMP22.W','PADD2 Import')[start:end]
#imp3_w=eia_w('PET.WCEIMP32.W','PADD3 Import')[start:end]
#imp4_w=eia_w('PET.WCEIMP42.W','PADD4 Import')[start:end]
#imp5_w=eia_w('PET.WCEIMP52.W','PADD5 Import')[start:end]
uti1_w=eia_w('PET.W_NA_YUP_R10_PER.W','PADD1 Utilization')[start:end]
uti2_w=eia_w('PET.W_NA_YUP_R20_PER.W','PADD2 Utilization')[start:end]
uti3_w=eia_w('PET.W_NA_YUP_R30_PER.W','PADD3 Utilization')[start:end]
uti4_w=eia_w('PET.W_NA_YUP_R40_PER.W','PADD4 Utilization')[start:end]
uti5_w=eia_w('PET.W_NA_YUP_R50_PER.W','PADD5 Utilization')[start:end]

fig, axes = plt.subplots(nrows=5, ncols=2)#周末库存、(均进口量、)均开工率
plot_seasonal(stock1_w,axes[0,0],"kb")
plot_seasonal(stock2_w,axes[1,0],"kb")
plot_seasonal(stock3_w,axes[2,0],"kb")
plot_seasonal(stock4_w,axes[4,0],"kb")
plot_seasonal(stock5_w,axes[3,0],"kb")
#plot_seasonal(imp1_w,axes[0,2],"kb/d")
#plot_seasonal(imp2_w,axes[1,2],"kb/d")
#plot_seasonal(imp3_w,axes[2,2],"kb/d")
#plot_seasonal(imp4_w,axes[4,2],"kb/d")
#plot_seasonal(imp5_w,axes[3,2],"kb/d")
plot_seasonal(uti1_w,axes[0,1],"%")
plot_seasonal(uti2_w,axes[1,1],"%")
plot_seasonal(uti3_w,axes[2,1],"%")
plot_seasonal(uti4_w,axes[4,1],"%")
plot_seasonal(uti5_w,axes[3,1],"%")

# %%
#Distillate Fuel Oil
stock1d_w=eia_w("PET.WDISTP11.W",'PADD1 Stock')[start:end]
stock2d_w=eia_w("PET.WDISTP21.W",'PADD2 Stock')[start:end]
stock3d_w=eia_w("PET.WDISTP31.W",'PADD3 Stock')[start:end]
stock4d_w=eia_w("PET.WDISTP41.W",'PADD4 Stock')[start:end]
stock5d_w=eia_w("PET.WDISTP51.W",'PADD5 Stock')[start:end]
prod1d_w=eia_w("PET.WDIRPP12.W",'PADD1 Production')[start:end]
prod2d_w=eia_w("PET.WDIRPP22.W",'PADD2 Production')[start:end]
prod3d_w=eia_w("PET.WDIRPP32.W",'PADD3 Production')[start:end]
prod4d_w=eia_w("PET.WDIRPP42.W",'PADD4 Production')[start:end]
prod5d_w=eia_w("PET.WDIRPP52.W",'PADD5 Production')[start:end]
#imp1d_w=eia_w('PET.WDIIM_R10-Z00_2.W','PADD1 Import')[start:end]

fig, axes = plt.subplots(nrows=5, ncols=2)#周末库存、均产量
plot_seasonal(stock1d_w,axes[0,0],"kb")
plot_seasonal(stock2d_w,axes[1,0],"kb")
plot_seasonal(stock3d_w,axes[2,0],"kb")
plot_seasonal(stock4d_w,axes[4,0],"kb")
plot_seasonal(stock5d_w,axes[3,0],"kb")
plot_seasonal(prod1d_w,axes[0,1],"kb/d")
plot_seasonal(prod2d_w,axes[1,1],"kb/d")
plot_seasonal(prod3d_w,axes[2,1],"kb/d")
plot_seasonal(prod4d_w,axes[4,1],"kb/d")
plot_seasonal(prod5d_w,axes[3,1],"kb/d")

# %%
#Total Motor Gasoline (stock - total, production - finished motor gasoline)
stock1g_w=eia_w("PET.WGTSTP11.W ",'PADD1 Stock')[start:end]
stock2g_w=eia_w("PET.WGTSTP21.W ",'PADD2 Stock')[start:end]
stock3g_w=eia_w("PET.WGTSTP31.W ",'PADD3 Stock')[start:end]
stock4g_w=eia_w("PET.WGTSTP41.W ",'PADD4 Stock')[start:end]
stock5g_w=eia_w("PET.WGTSTP51.W ",'PADD5 Stock')[start:end]
prod1g_w=eia_w("PET.WGFRPP12.W",'PADD1 Production')[start:end]
prod2g_w=eia_w("PET.WGFRPP22.W",'PADD2 Production')[start:end]
prod3g_w=eia_w("PET.WGFRPP32.W",'PADD3 Production')[start:end]
prod4g_w=eia_w("PET.WGFRPP42.W",'PADD4 Production')[start:end]
prod5g_w=eia_w("PET.WGFRPP52.W",'PADD5 Production')[start:end]
#imp1g_w=eia_w('PET.WGTIM_R10-Z00_2.W','PADD1 Import')[start:end]

fig, axes = plt.subplots(nrows=5, ncols=2)#周末库存、均产量
plot_seasonal(stock1g_w,axes[0,0],"kb")
plot_seasonal(stock2g_w,axes[1,0],"kb")
plot_seasonal(stock3g_w,axes[2,0],"kb")
plot_seasonal(stock4g_w,axes[4,0],"kb")
plot_seasonal(stock5g_w,axes[3,0],"kb")

plot_seasonal(prod1g_w,axes[0,1],"kb/d")
plot_seasonal(prod2g_w,axes[1,1],"kb/d")
plot_seasonal(prod3g_w,axes[2,1],"kb/d")
plot_seasonal(prod4g_w,axes[4,1],"kb/d")
plot_seasonal(prod5g_w,axes[3,1],"kb/d")
