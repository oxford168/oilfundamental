# %%
#!pip install EIA_python
#!pip install requests
import pandas as pd
from dateutil.relativedelta import *

# %%
filename = 'Y:\\10-Analysis\\a油价分析模型 202108\\Oil Report\\EIA STEO\\apr19_base.xlsx'
EIADates=pd.read_excel(open(filename, 'rb'),sheet_name='Dates',header=None)
dates = pd.to_datetime(EIADates.iloc[10,2:74].astype(int),format='%Y%m')
df=pd.read_excel(open(filename, 'rb'),sheet_name='3atab')
TotalStockDraw=pd.Series(df.iloc[40,2:74].array,dates.array)
ForecastMonth=pd.to_datetime(EIADates.iloc[0,3],format='%B %Y')

# %%
ForecastMonth
# Out:
# Timestamp('2019-04-01 00:00:00')

# %%
df
# Out:
#       Table of Contents  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4             papr_oecd
# 5               papr_us
# 6               papr_ca
# 7               papr_mx
# 8        papr_otheroecd
# 9          papr_nonoecd
# 10            papr_opec
# 11            copr_opec
# 12              opec_nc
# 13             papr_fsu
# 14              papr_ch
# 15   papr_other_nonoecd
# 16           papr_world
# 17                  NaN
# 18         papr_nonopec
# 19                  NaN
# 20                  NaN
# 21            patc_oecd
# 22              patc_us
# 23             patc_ust
# 24              patc_ca
# 25     patc_oecd_europe
# 26              patc_ja
# 27      patc_other_oecd
# 28        patc_non_oecd
# 29             patc_fsu
# 30  patc_nonoecd_europe
# 31              patc_ch
# 32      patc_other_asia
# 33   patc_other_nonoecd
# 34           patc_world
# 35                  NaN
# 36                  NaN
# ...
