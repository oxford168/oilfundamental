# %%
from cornerstone import *

# %%
start='2014-01-03'
end='2018-11-05'
rcParams['figure.figsize'] = 18, 18

# %%
#Crude Oil Stock & Production
USCRSTK1W=eia_w(apicode['CRSTK1W'],'USCRSTK1W')[start:end]
USCRSTK2W=eia_w(apicode['CRSTK2W'],'USCRSTK2W')[start:end]
USCRSTK3W=eia_w(apicode['CRSTK3W'],'USCRSTK3W')[start:end]
USCRSTK4W=eia_w(apicode['CRSTK4W'],'USCRSTK4W')[start:end]
USCRSTK5W=eia_w(apicode['CRSTK5W'],'USCRSTK5W')[start:end]
USCRUTI1W=eia_w(apicode['CRUTI1W'],'USCRUTI1W')[start:end]
USCRUTI2W=eia_w(apicode['CRUTI2W'],'USCRUTI2W')[start:end]
USCRUTI3W=eia_w(apicode['CRUTI3W'],'USCRUTI3W')[start:end]
USCRUTI4W=eia_w(apicode['CRUTI4W'],'USCRUTI4W')[start:end]
USCRUTI5W=eia_w(apicode['CRUTI5W'],'USCRUTI5W')[start:end]

fig, axes = plt.subplots(nrows=5, ncols=2)
plot_seasonal(USCRSTK1W,axes[0,0],"kb")
plot_seasonal(USCRSTK2W,axes[1,0],"kb")
plot_seasonal(USCRSTK3W,axes[2,0],"kb")
plot_seasonal(USCRSTK4W,axes[3,0],"kb")
plot_seasonal(USCRSTK5W,axes[4,0],"kb")
plot_seasonal(USCRUTI1W,axes[0,1],"%")
plot_seasonal(USCRUTI2W,axes[1,1],"%")
plot_seasonal(USCRUTI3W,axes[2,1],"%")
plot_seasonal(USCRUTI4W,axes[3,1],"%")
plot_seasonal(USCRUTI5W,axes[4,1],"%")

# %%
#Distillate Fuel Oil Stock & Production
USGOSTK1W=eia_w(apicode['GOSTK1W'],'USGOSTK1W')[start:end]
USGOSTK2W=eia_w(apicode['GOSTK2W'],'USGOSTK2W')[start:end]
USGOSTK3W=eia_w(apicode['GOSTK3W'],'USGOSTK3W')[start:end]
USGOSTK4W=eia_w(apicode['GOSTK4W'],'USGOSTK4W')[start:end]
USGOSTK5W=eia_w(apicode['GOSTK5W'],'USGOSTK5W')[start:end]
USGOPROD1W=eia_w(apicode['GOPROD1W'],'USPROD1W')[start:end]
USGOPROD2W=eia_w(apicode['GOPROD2W'],'USPROD2W')[start:end]         
USGOPROD3W=eia_w(apicode['GOPROD3W'],'USPROD3W')[start:end]
USGOPROD4W=eia_w(apicode['GOPROD4W'],'USPROD4W')[start:end]
USGOPROD5W=eia_w(apicode['GOPROD5W'],'USPROD5W')[start:end]

fig, axes = plt.subplots(nrows=5, ncols=2)
plot_seasonal(USGOSTK1W,axes[0,0],"kb")
plot_seasonal(USGOSTK2W,axes[1,0],"kb")
plot_seasonal(USGOSTK3W,axes[2,0],"kb")
plot_seasonal(USGOSTK4W,axes[3,0],"kb")
plot_seasonal(USGOSTK5W,axes[4,0],"kb")
plot_seasonal(USGOPROD1W,axes[0,1],"kb/d")
plot_seasonal(USGOPROD2W,axes[1,1],"kb/d")
plot_seasonal(USGOPROD3W,axes[2,1],"kb/d")
plot_seasonal(USGOPROD4W,axes[3,1],"kb/d")
plot_seasonal(USGOPROD5W,axes[4,1],"kb/d")

# %%
#Total Motor Gasoline Stock (Total) & Production (Finished Motor Gasoline)
USRBSTK1W=eia_w(apicode['RBSTK1W'],'USRBSTK1W')[start:end]
USRBSTK2W=eia_w(apicode['RBSTK2W'],'USRBSTK2W')[start:end]
USRBSTK3W=eia_w(apicode['RBSTK3W'],'USRBSTK3W')[start:end]
USRBSTK4W=eia_w(apicode['RBSTK4W'],'USRBSTK4W')[start:end]
USRBSTK5W=eia_w(apicode['RBSTK5W'],'USRBSTK5W')[start:end]
USRBPROD1W=eia_w(apicode['RBPROD1W'],'USRBPROD1W')[start:end]
USRBPROD2W=eia_w(apicode['RBPROD2W'],'USRBPROD2W')[start:end]
USRBPROD3W=eia_w(apicode['RBPROD3W'],'USRBPROD3W')[start:end]
USRBPROD4W=eia_w(apicode['RBPROD4W'],'USRBPROD4W')[start:end]
USRBPROD5W=eia_w(apicode['RBPROD5W'],'USRBPROD5W')[start:end]

fig, axes = plt.subplots(nrows=5, ncols=2)
plot_seasonal(USRBSTK1W,axes[0,0],"kb")
plot_seasonal(USRBSTK2W,axes[1,0],"kb")
plot_seasonal(USRBSTK3W,axes[2,0],"kb")
plot_seasonal(USRBSTK4W,axes[3,0],"kb")
plot_seasonal(USRBSTK5W,axes[4,0],"kb")
plot_seasonal(USRBPROD1W,axes[0,1],"kb/d")
plot_seasonal(USRBPROD2W,axes[1,1],"kb/d")
plot_seasonal(USRBPROD3W,axes[2,1],"kb/d")
plot_seasonal(USRBPROD4W,axes[3,1],"kb/d")
plot_seasonal(USRBPROD5W,axes[4,1],"kb/d")
